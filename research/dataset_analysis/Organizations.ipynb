# %% [markdown]
# # Organizations
#
# Dataset info:
#
# ICO - Identification Number
#
# DIC - Tax identification number
#
# VAT payer - whether the company is a VAT payer
#
# IC DPH - VAT identification number
#
# There are only 2 organizations out of 244 from Czech Republic, others are from Slvoakia

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Organizations. Categories

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Shortened categories

# %% [markdown]
# ![image.png](attachment:image.png)
