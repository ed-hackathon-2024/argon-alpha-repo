# %% [markdown]
# # Product Analysis K + Z

# %% [markdown]
# Products dataset analytics:
#
# 5969 entries,
#
# 14 columns:
#
# 8 categorical
#
# 2 numerical,
#
# 2 time,
#
# 1 text

# %% [markdown]
# ### Feature statistics

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Group by categories, sort by the number of products in each category

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Group by categories, sort by Price - mean

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Group by categories, sort by VAT rate - mean

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Group by shortened categories, sort by Price - mean

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Group by shortened categories, sort by VAT rate - mean

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Group by shortened categories, sort by the number of products in each category

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Group by shortened categories, sort by the overall value - sum of prices

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Group by item_type
#
# from the analysis below we see that Z - is "zlava", and K is an unual transaction

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We need some kind of comaparison between the amount and prices
