# %% [markdown]
# # Product Analysis Z

# %% [markdown]
# Products dataset analytics:
#
# 5969 entries,
#
# 14 columns:
#
# 8 categorical
#
# 2 numerical,
#
# 2 time,
#
# 1 text

# %% [markdown]
# ### Group by shortened categories, sort by Price - mean

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Sort by shortened categories. Sum of prices

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Group by shortened categories, sort by the number of products in each category

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
