# %% [markdown]
# # TimeLine analysis
#
# Using timelines in Line Charts

# %% [markdown]
# ### Auto

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Baby

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Basic

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Dairy

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Drinks

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Drugstore

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Eating

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Fashion

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Free-time

# %% [markdown]
# ![image.png](attachment:image.png)
